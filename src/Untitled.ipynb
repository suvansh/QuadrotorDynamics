# %%
using IterativeLQR
using StaticArrays
using LinearAlgebra
using Plots
using QuadrotorDynamics
using Symbolics
# Out:
# ┌ Info: Precompiling QuadrotorDynamics [f6d16423-25c2-4b6a-a4a4-258ba236e06a]
# └ @ Base loading.jl:1342

# %%
function Dynamics(f::Function, nx::Int, nu::Int; nw::Int=0)
    #TODO: option to load/save methods
    @variables x[1:nx], u[1:nu], w[1:nw] 
    y = f(x, u, w) 
    jacx = Symbolics.jacobian(y, x);
    jacu = Symbolics.jacobian(y, u);
    val_func = eval(Symbolics.build_function(y, x, u, w)[2]);
    jacx_func = eval(Symbolics.build_function(jacx, x, u, w)[2]);
    jacu_func = eval(Symbolics.build_function(jacu, x, u, w)[2]);
    ny = length(y)

    return IterativeLQR.Dynamics(val_func, jacx_func, jacu_func, 
                    ny, nx, nu, nw, 
                    zeros(ny), zeros(ny, nx), zeros(ny, nu))
end

function Cost(f::Function, nx::Int, nu::Int; nw::Int=0)
    #TODO: option to load/save methods
    @variables x[1:nx], u[1:nu], w[1:nw]
    
    val = f(x, u, w)
    gradx = Symbolics.gradient(val, x)
    gradu = Symbolics.gradient(val, u) 
    hessxx = Symbolics.jacobian(gradx, x) 
    hessuu = Symbolics.jacobian(gradu, u) 
    hessux = Symbolics.jacobian(gradu, x) 

    val_func = eval(Symbolics.build_function([val], x, u, w)[2])
    gradx_func = eval(Symbolics.build_function(gradx, x, u, w)[2])
    gradu_func = eval(Symbolics.build_function(gradu, x, u, w)[2])
    hessxx_func = eval(Symbolics.build_function(hessxx, x, u, w)[2])
    hessuu_func = eval(Symbolics.build_function(hessuu, x, u, w)[2])
    hessux_func = eval(Symbolics.build_function(hessux, x, u, w)[2])  

    return IterativeLQR.Cost(val_func, 
        gradx_func, gradu_func, 
        hessxx_func, hessuu_func, hessux_func,
        zeros(1), 
        zeros(nx), zeros(nu), 
        zeros(nx, nx), zeros(nu, nu), zeros(nu, nx))
end
# Out:
# Cost (generic function with 1 method)

# %%
# ## horizon 
T = 101 
dt = 0.01

# ## quadrotor
nx = 13 
nu = 4
nw = 0 

# ## model
rotor = Rotor(2, 0.165, 0.018, 0.0, 0.005, 0.010, 0.004, 0.0048, 0.0048*sqrt(0.0024), 6.8*π/180, 14.6*π/180, 5.5)
quad = QuadRotor(4., SMatrix{3,3}(Diagonal([0.082, 0.082, 0.149])), -0.007, 0.315, 0.05, rotor, false)
dyn = Dynamics((x, u, w) -> QuadrotorDynamics.step(quad, x, u; h=dt), nx, nu; nw=nw)
model = [dyn for t = 1:T-1]

# ## initialization
x1 = [1; 0; 0; 1; zeros(3); zeros(3); zeros(3)]
xT = [zeros(3); 1; zeros(3); zeros(3); zeros(3)]
ū = [1.0 * randn(nu) for t = 1:T-1] 
w = [zeros(nw) for t = 1:T]
x̄ = rollout(model, x1, ū, w)

# ## objective 
# Bryson's rule: max position deviation ~5, max rad/sec ~1500, 
ot = (x, u, w) -> 1/(5^2) * (dot(x[1:3], x[1:3]) + dot(x[8:13], x[8:13])) + 1/(1500^2) * dot(u, u)
oT = (x, u, w) -> 0.1 * (dot((x-xT)[1:3], (x-xT)[1:3]) + dot((x-xT)[8:13], (x-xT)[8:13]))
ct = Cost(ot, nx, nu; nw=nw)
cT = Cost(oT, nx, 0; nw=nw)
obj = [[ct for t = 1:T-1]..., cT]

# ## constraints
goal(x, u, w) = x - xT

cont = Constraint()
conT = Constraint(goal, nx, 0)
cons = [[cont for t = 1:T-1]..., conT] 

# ## problem
prob = solver(model, obj, cons)
initialize_controls!(prob, ū)
initialize_states!(prob, x̄)

# ## solve
solve!(prob)

# ## solution
x_sol, u_sol = get_trajectory(prob)
# Out:
# InterruptException:
#
# Stacktrace:
#    [1] _zip_iterate_interleave
#      @ ./iterators.jl:380 [inlined]
#    [2] _zip_iterate_all(is::Tuple{Base.Iterators.Filter{Base.var"#76#77"{typeof(SymbolicUtils.is_literal_number)}, Vector{Any}}, Base.Iterators.Filter{Base.var"#76#77"{typeof(SymbolicUtils.is_literal_number)}, Vector{Any}}}, ss::Tuple{Tuple{}, Tuple{}})
#      @ Base.Iterators ./iterators.jl:364
#    [3] iterate
#      @ ./iterators.jl:350 [inlined]
#    [4] cmp_term_term(a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:81
#    [5] <ₑ(a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20
#    [6] cmp_term_term(a::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:84
#    [7] <ₑ(a::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20
#    [8] cmp_term_term(a::SymbolicUtils.Term{Real, Nothing}, b::SymbolicUtils.Term{Real, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:82
# --- the last 2 lines are repeated 2 more times ---
#   [13] <ₑ(a::SymbolicUtils.Term{Real, Nothing}, b::SymbolicUtils.Term{Real, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20
#   [14] cmp_term_term(a::SymbolicUtils.Pow{Real, SymbolicUtils.Term{Real, Nothing}, Int64, Nothing}, b::SymbolicUtils.Pow{Real, SymbolicUtils.Term{Real, Nothing}, Int64, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:84
#   [15] <ₑ(a::SymbolicUtils.Pow{Real, SymbolicUtils.Term{Real, Nothing}, Int64, Nothing}, b::SymbolicUtils.Pow{Real, SymbolicUtils.Term{Real, Nothing}, Int64, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20
#   [16] cmp_term_term(a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:82
#   [17] <ₑ(a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20
#   [18] cmp_term_term(a::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:84
# --- the last 2 lines are repeated 2 more times ---
#   [23] <ₑ(a::SymbolicUtils.Mul{Real, Int64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Mul{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20
#   [24] cmp_term_term(a::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:82
#   [25] <ₑ(a::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20
#   [26] cmp_term_term(a::SymbolicUtils.Term{Real, Nothing}, b::SymbolicUtils.Term{Real, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:84
# --- the last 4 lines are repeated 2 more times ---
#   [35] <ₑ(a::SymbolicUtils.Add{Real, Float64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Add{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20
#   [36] cmp_term_term(a::SymbolicUtils.Term{Real, Nothing}, b::SymbolicUtils.Term{Real, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:84
# --- the last 2 lines are repeated 2 more times ---
#   [41] <ₑ(a::SymbolicUtils.Term{Real, Nothing}, b::SymbolicUtils.Term{Real, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20
#   [42] cmp_term_term(a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:82
#   [43] <ₑ(a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20
#   [44] cmp_term_term(a::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:84
#   [45] <ₑ(a::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20
#   [46] cmp_term_term(a::SymbolicUtils.Mul{Real, Int64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Mul{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:82
# --- the last 2 lines are repeated 3 more times ---
#   [53] <ₑ
#      @ ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20 [inlined]
#   [54] #1
#      @ ./ordering.jl:125 [inlined]
#   [55] lt(o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}}, a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ Base.Order ./ordering.jl:112
#   [56] sort!(v::Vector{SymbolicUtils.Symbolic{Real}}, lo::Int64, hi::Int64, #unused#::Base.Sort.InsertionSortAlg, o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}})
#      @ Base.Sort ./sort.jl:502
#   [57] sort!(v::Vector{SymbolicUtils.Symbolic{Real}}, lo::Int64, hi::Int64, a::Base.Sort.MergeSortAlg, o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}}, t::Vector{SymbolicUtils.Symbolic{Real}})
#      @ Base.Sort ./sort.jl:587
#   [58] sort!
#      @ ./sort.jl:586 [inlined]
#   [59] sort!
#      @ ./sort.jl:657 [inlined]
#   [60] #sort!#8
#      @ ./sort.jl:717 [inlined]
#   [61] arguments(a::SymbolicUtils.Add{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/types.jl:601
#   [62] arglength(a::SymbolicUtils.Add{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:11
#   [63] cmp_term_term(a::SymbolicUtils.Add{Real, Float64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Pow{Real, SymbolicUtils.Term{Real, Nothing}, Int64, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:50
#   [64] <ₑ
#      @ ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20 [inlined]
#   [65] #1
#      @ ./ordering.jl:125 [inlined]
#   [66] lt(o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}}, a::SymbolicUtils.Add{Real, Float64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Pow{Real, SymbolicUtils.Term{Real, Nothing}, Int64, Nothing})
#      @ Base.Order ./ordering.jl:112
#   [67] sort!(v::Vector{SymbolicUtils.Symbolic{Real}}, lo::Int64, hi::Int64, #unused#::Base.Sort.InsertionSortAlg, o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}})
#      @ Base.Sort ./sort.jl:502
#   [68] sort!(v::Vector{SymbolicUtils.Symbolic{Real}}, lo::Int64, hi::Int64, a::Base.Sort.MergeSortAlg, o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}}, t::Vector{SymbolicUtils.Symbolic{Real}})
#      @ Base.Sort ./sort.jl:587
#   [69] sort!
#      @ ./sort.jl:586 [inlined]
#   [70] sort!
#      @ ./sort.jl:657 [inlined]
#   [71] #sort!#8
#      @ ./sort.jl:717 [inlined]
#   [72] arguments(a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/types.jl:744
#   [73] arglength(a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:11
#   [74] cmp_term_term(a::SymbolicUtils.Mul{Real, Int64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:51
#   [75] <ₑ
#      @ ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20 [inlined]
#   [76] #1
#      @ ./ordering.jl:125 [inlined]
#   [77] lt(o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}}, a::SymbolicUtils.Mul{Real, Int64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ Base.Order ./ordering.jl:112
#   [78] sort!(v::Vector{SymbolicUtils.Mul{Real, T, Dict{Any, Number}, Nothing} where T<:Number}, lo::Int64, hi::Int64, #unused#::Base.Sort.InsertionSortAlg, o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}})
#      @ Base.Sort ./sort.jl:502
#   [79] sort!(v::Vector{SymbolicUtils.Mul{Real, T, Dict{Any, Number}, Nothing} where T<:Number}, lo::Int64, hi::Int64, a::Base.Sort.MergeSortAlg, o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}}, t::Vector{SymbolicUtils.Mul{Real, T, Dict{Any, Number}, Nothing} where T<:Number})
#      @ Base.Sort ./sort.jl:587
#   [80] sort!
#      @ ./sort.jl:586 [inlined]
#   [81] sort!
#      @ ./sort.jl:657 [inlined]
#   [82] #sort!#8
#      @ ./sort.jl:717 [inlined]
#   [83] arguments(a::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/types.jl:601
#   [84] arglength(a::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:11
#   [85] cmp_term_term(a::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:51
#   [86] <ₑ(a::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20
#   [87] cmp_term_term(a::SymbolicUtils.Term{Real, Nothing}, b::SymbolicUtils.Term{Real, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:82
#   [88] <ₑ
#      @ ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20 [inlined]
#   [89] #1
#      @ ./ordering.jl:125 [inlined]
#   [90] lt(o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}}, a::SymbolicUtils.Term{Real, Nothing}, b::SymbolicUtils.Term{Real, Nothing})
#      @ Base.Order ./ordering.jl:112
#   [91] sort!(v::Vector{SymbolicUtils.Symbolic{Real}}, lo::Int64, hi::Int64, #unused#::Base.Sort.InsertionSortAlg, o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}})
#      @ Base.Sort ./sort.jl:502
#   [92] sort!(v::Vector{SymbolicUtils.Symbolic{Real}}, lo::Int64, hi::Int64, a::Base.Sort.MergeSortAlg, o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}}, t::Vector{SymbolicUtils.Symbolic{Real}})
#      @ Base.Sort ./sort.jl:587
#   [93] sort!
#      @ ./sort.jl:586 [inlined]
#   [94] sort!
#      @ ./sort.jl:657 [inlined]
#   [95] #sort!#8
#      @ ./sort.jl:717 [inlined]
#   [96] arguments(a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/types.jl:744
#   [97] arglength(a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:11
#   [98] cmp_term_term(a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:50
#   [99] <ₑ
#      @ ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20 [inlined]
#  [100] #1
#      @ ./ordering.jl:125 [inlined]
#  [101] lt
#      @ ./ordering.jl:112 [inlined]
#  [102] sort!(v::Vector{SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing}}, lo::Int64, hi::Int64, #unused#::Base.Sort.InsertionSortAlg, o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}})
#      @ Base.Sort ./sort.jl:502
#  [103] sort!(v::Vector{SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing}}, lo::Int64, hi::Int64, a::Base.Sort.MergeSortAlg, o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}}, t::Vector{SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing}})
#      @ Base.Sort ./sort.jl:587
#  [104] sort!
#      @ ./sort.jl:586 [inlined]
#  [105] sort!
#      @ ./sort.jl:657 [inlined]
#  [106] #sort!#8
#      @ ./sort.jl:717 [inlined]
#  [107] arguments(a::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/types.jl:601
#  [108] arglength(a::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:11
#  [109] cmp_term_term(a::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:51
#  [110] <ₑ
#      @ ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20 [inlined]
#  [111] #1
#      @ ./ordering.jl:125 [inlined]
#  [112] lt
#      @ ./ordering.jl:112 [inlined]
#  [113] sort!(v::Vector{SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing}}, lo::Int64, hi::Int64, #unused#::Base.Sort.InsertionSortAlg, o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}})
#      @ Base.Sort ./sort.jl:502
#  [114] sort!(v::Vector{SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing}}, lo::Int64, hi::Int64, a::Base.Sort.MergeSortAlg, o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}}, t::Vector{SymbolicUtils.Add{Real, Int64, Dict{Any, Number}, Nothing}})
#      @ Base.Sort ./sort.jl:587
#  [115] sort!
#      @ ./sort.jl:586 [inlined]
#  [116] sort!
#      @ ./sort.jl:657 [inlined]
#  [117] #sort!#8
#      @ ./sort.jl:717 [inlined]
#  [118] arguments(a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/types.jl:744
#  [119] arglength(a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:11
#  [120] cmp_term_term(a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:51
#  [121] <ₑ
#      @ ~/.julia/packages/SymbolicUtils/kZD5O/src/ordering.jl:20 [inlined]
#  [122] #1
#      @ ./ordering.jl:125 [inlined]
#  [123] lt(o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}}, a::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing}, b::SymbolicUtils.Mul{Real, Float64, Dict{Any, Number}, Nothing})
#      @ Base.Order ./ordering.jl:112
#  [124] sort!(v::Vector{SymbolicUtils.Symbolic{Real}}, lo::Int64, hi::Int64, #unused#::Base.Sort.InsertionSortAlg, o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}})
#      @ Base.Sort ./sort.jl:502
#  [125] sort!(v::Vector{SymbolicUtils.Symbolic{Real}}, lo::Int64, hi::Int64, a::Base.Sort.MergeSortAlg, o::Base.Order.Lt{Base.Order.var"#1#3"{typeof(SymbolicUtils.:<ₑ), typeof(identity)}}, t::Vector{SymbolicUtils.Symbolic{Real}})
#      @ Base.Sort ./sort.jl:587
#  [126] sort!
#      @ ./sort.jl:586 [inlined]
#  [127] sort!
#      @ ./sort.jl:657 [inlined]
#  [128] #sort!#8
#      @ ./sort.jl:717 [inlined]
#  [129] arguments(a::SymbolicUtils.Add{Real, Float64, Dict{Any, Number}, Nothing})
#      @ SymbolicUtils ~/.julia/packages/SymbolicUtils/kZD5O/src/types.jl:601
#  [130] hasderiv(O::SymbolicUtils.Add{Real, Float64, Dict{Any, Number}, Nothing})
#      @ Symbolics ~/.julia/packages/Symbolics/4rq0M/src/diff.jl:70
#  [131] expand_derivatives(O::SymbolicUtils.Add{Real, Float64, Dict{Any, Number}, Nothing}, simplify::Bool; occurances::Nothing)
#      @ Symbolics ~/.julia/packages/Symbolics/4rq0M/src/diff.jl:154
#  [132] expand_derivatives(O::SymbolicUtils.Add{Real, Float64, Dict{Any, Number}, Nothing}, simplify::Bool)
#      @ Symbolics ~/.julia/packages/Symbolics/4rq0M/src/diff.jl:78
#  [133] expand_derivatives(O::SymbolicUtils.Term{Real, Nothing}, simplify::Bool; occurances::Nothing)
#      @ Symbolics ~/.julia/packages/Symbolics/4rq0M/src/diff.jl:80
#  [134] expand_derivatives(O::SymbolicUtils.Term{Real, Nothing}, simplify::Bool)
#      @ Symbolics ~/.julia/packages/Symbolics/4rq0M/src/diff.jl:78
#  [135] jacobian(ops::Vector{Num}, vars::Vector{Num}; simplify::Bool)
#      @ Symbolics ~/.julia/packages/Symbolics/4rq0M/src/diff.jl:325
#  [136] jacobian(ops::Vector{Num}, vars::Vector{Num})
#      @ Symbolics ~/.julia/packages/Symbolics/4rq0M/src/diff.jl:325
#  [137] Dynamics(f::var"#15#16", nx::Int64, nu::Int64; nw::Int64)
#      @ Main ./In[2]:5
#  [138] top-level scope
#      @ In[3]:13
#  [139] eval
#      @ ./boot.jl:360 [inlined]

# %%
# ## horizon 
T = 101 

# ## acrobot 
nx = 4 
nu = 1 
nw = 0 

function acrobot(x, u, w)
    mass1 = 1.0  
    inertia1 = 0.33  
    length1 = 1.0 
    lengthcom1 = 0.5 

    mass2 = 1.0  
    inertia2 = 0.33  
    length2 = 1.0 
    lengthcom2 = 0.5 

    gravity = 9.81 
    friction1 = 0.1 
    friction2 = 0.1

    function M(x, w)
        a = (inertia1 + inertia2 + mass2 * length1 * length1
            + 2.0 * mass2 * length1 * lengthcom2 * cos(x[2]))

        b = inertia2 + mass2 * length1 * lengthcom2 * cos(x[2])

        c = inertia2

       return [a b; b c]
    end

    function τ(x, w)
        a = (-1.0 * mass1 * gravity * lengthcom1 * sin(x[1])
            - mass2 * gravity * (length1 * sin(x[1])
            + lengthcom2 * sin(x[1] + x[2])))

        b = -1.0 * mass2 * gravity * lengthcom2 * sin(x[1] + x[2])

        return [a; b]
    end

    function C(x, w)
        a = -2.0 * mass2 * length1 * lengthcom2 * sin(x[2]) * x[4]
        b = -1.0 * mass2 * length1 * lengthcom2 * sin(x[2]) * x[4]
        c = mass2 * length1 * lengthcom2 * sin(x[2]) * x[3]
        d = 0.0

        return [a b; c d]
    end

    function B(x, w)
        [0.0; 1.0]
    end

    q = view(x, 1:2)
    v = view(x, 3:4)

    qdd = M(q, w) \ (-1.0 * C(x, w) * v
            + τ(q, w) + B(q, w) * u[1] - [friction1; friction2] .* v)

    return [x[3]; x[4]; qdd[1]; qdd[2]]
end

function midpoint_explicit(x, u, w)
    h = 0.1 # timestep 
    x + h * acrobot(x + 0.5 * h * acrobot(x, u, w), u, w)
end

# ## model
dyn = Dynamics(midpoint_explicit, nx, nu; nw=nw)
model = [dyn for t = 1:T-1] 

# ## initialization
x1 = [0.0; 0.0; 0.0; 0.0] 
xT = [0.0; π; 0.0; 0.0]
ū = [1.0 * randn(nu) for t = 1:T-1] 
w = [zeros(nw) for t = 1:T]
x̄ = rollout(model, x1, ū, w)

# ## objective 
ot = (x, u, w) -> 0.1 * dot(x[3:4], x[3:4]) + 0.1 * dot(u, u)
oT = (x, u, w) -> 0.1 * dot(x[3:4], x[3:4])
ct = Cost(ot, nx, nu; nw=nw)
cT = Cost(oT, nx, 0; nw=nw)
obj = [[ct for t = 1:T-1]..., cT]

# ## constraints
goal(x, u, w) = x - xT

cont = Constraint()
conT = Constraint(goal, nx, 0)
cons = [[cont for t = 1:T-1]..., conT] 

# ## problem
prob = solver(model, obj, cons)
initialize_controls!(prob, ū)
initialize_states!(prob, x̄)

# ## solve
solve!(prob)

# ## solution
x_sol, u_sol = get_trajectory(prob)

# ## visuals
plot(hcat(x_sol...)')
plot(hcat(u_sol...)', linetype=:steppost)
